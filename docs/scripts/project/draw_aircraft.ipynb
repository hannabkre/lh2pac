# %%
from gemseo_oad_training.utils import draw_aircraft
from gemseo_oad_training.utils import AircraftConfiguration

# %%
# AircraftConfiguration??

# %%
AC1 =AircraftConfiguration(name = 'test', length = 50, color = 'blue')
AC2 =AircraftConfiguration(name = 'test2')

# %%
draw_aircraft??
# Out:
# Signature:
# draw_aircraft(
#     *configurations: 'AircraftConfiguration',
#     title: 'str' = '',
#     file_path: 'Path | str' = 'aircraft_3d.png',
#     save: 'bool' = False,
#     show: 'bool' = False,
#     color: 'str' = 'white',
# ) -> 'None'
# Source:
# def draw_aircraft(
#     *configurations: AircraftConfiguration,
#     title: str = "",
#     file_path: Path | str = "aircraft_3d.png",
#     save: bool = False,
#     show: bool = False,
#     color: str = "white",
# ) -> None:
#     """Draw aircraft configurations from the front, top and side.
#
#     Args:
#         *configurations: The aircraft configurations if any.
#             Otherwise, use the default one.
#         title: The title of the figure.
#         file_path: The file path to save the figure.
#         save: Whether to save the figure.
#         show: Whether to display the figure.
#         color: The color of the aircraft face if there is only one configuration.
# ...

# %%
draw_aircraft(AC1, AC2, title="Area = 200")
